# %% [markdown]
# # This is the first graph that shows:
# 1.   All **good data** as dots of one color. (Green)
# 2.   The average represented as an error bar that has been calculated to match the standard deviation of the **good data**.

# %%
# Importing libraries
import numpy as np
import matplotlib.pyplot as plt

# Assigning Data to their respetive arrays and variables
yData = np.array([1.31, 1.41, 1.63, 1.43, 1.59, 1.53, 1.51, 1.44, 1.34, 1.43])
avgData = np.average(yData)

# A better graph requires more lines that add the required formatting
plt.plot(ydata, 'o' ,color='g', label="Period (s)")
plt.errorbar(10, avgData, np.std(yData), 0,  'x' ,color="b", label="Average")

# Remove x-axis
plt.gca().get_xaxis().set_visible(False)

# Print average and standard deviation
print("This is the average of the data: ", avgData)
print("This is the standard deviation of the data: ", np.std(yData))

# Graph Metadata
plt.ylabel("Period in Seconds")
plt.title("Period of the Pendulum Group #8")
plt.xlim([-0.5,11.5])
plt.ylim([1,2])
plt.legend()
plt.grid()
plt.show()
# Out:
# This is the average of the data:  1.462
# This is the standard deviation of the data:  0.09734474818910364

# %% [markdown]
# # This is the second graph that shows:
# 1. All **good data** as dots of one color. (Green)
# 2. All **bad data** as dots of another color. (Red)

# %%
# Importing libraries
import numpy as np
import matplotlib.pyplot as plt

# Assigning Data to their respetive arrays
yData = np.array([1.31, 1.41, 1.63, 1.43, 1.59, 1.53, 1.51, 1.44, 1.34, 1.43])
badData = np.array([1.8, 1.7, 1.9])

avgData = np.average(yData)

# A better graph requires more lines that add the required formatting
plt.plot(ydata, 'o' ,color='g', label="Period (s)")
plt.plot(badData, 'x' ,color='r', label="Period (s)")

# Remove x-axis
plt.gca().get_xaxis().set_visible(False)

# Metadata
plt.ylabel("Period in Seconds")
plt.title("Period of the Pendulum Group #8")
plt.xlim([-0.5,11.5])
plt.ylim([1,2])
plt.legend()
plt.grid()
plt.show()
